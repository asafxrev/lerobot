# %%
from lerobot.envs.utils import _load_module_from_path, _call_make_env, _normalize_hub_result

# Load your module
module = _load_module_from_path("./inverted_pendulum_env.py")

# Test the make_env function
result = _call_make_env(module, n_envs=1, use_async_envs=False)
normalized = _normalize_hub_result(result)

# Verify it works
suite_name = next(iter(normalized))
env = normalized[suite_name][0]
step_log = []

obs, info = env.reset()
reward = 0.0; terminated = False; truncated = False

# %%
# mjmodel = env.envs[0].unwrapped.model

# import mujoco as mj
# cart_id = mj.mj_name2id(mjmodel, mj.mjtObj.mjOBJ_BODY, "cart")
# pole_id = mj.mj_name2id(mjmodel, mj.mjtObj.mjOBJ_BODY, "pole")

# m_c = mjmodel.body_mass[cart_id]
# m_p = mjmodel.body_mass[pole_id]
# l = 1
# g = 9.81

# %%
n_episodes = 10
g = 9.81
max_theta = 0.2 # radians
max_u = 3.0

import numpy as np
def pid_policy(obs, prev_step_df, debug=True) -> np.ndarray:
    x, theta, dx, dtheta = obs[0]
    df = prev_step_df
    if len(df) == 0:
        theta_sum = 0.0
    else:
        theta_sum = df.theta.sum()
    # u = (-1.1 * g * theta) + (-0.6 * g * dtheta) + (0 * theta_sum)
    u_coeff = (
        (-0.3 * theta / max_theta) 
        + (-0.25 * dtheta) 
        + (-0.01 * theta_sum / max(len(df), 1))
        + (-0.2 * x)
    )
    u_coeff = u_coeff * 2.0  # Scale up 
    u_coeff = -u_coeff  # The force is already applied in the opposite (push, not a pull)
    # u_coeff = 0 if len(df) == 0 else 3 * np.sign(theta)  # Playing around with max force
    u = np.clip(u_coeff, -1, 1) * max_u
    return np.array([[u]])


step_log = [
]

def log_step(episode, step, 
             action, post_action_obs, terminated=False, truncated=False, 
             reward=[0.0], info={}):
    x, theta, dx, dtheta = post_action_obs[0]
    step_log.append(
        dict(
            episode=episode,
            step=step,
            action=action,
            u=action[0][0] if action is not None else 0.0,
            x=x,
            theta=theta,
            dx=dx,
            dtheta=dtheta,
            obs=post_action_obs,
            reward=reward[0] if reward is not None else 0.0,
            terminated=terminated,
            truncated=truncated,
            info=info,
        )
    )

import pandas as pd
def make_step_df():
    df = pd.DataFrame.from_records(step_log)
    return df


import time
for episode in range(n_episodes):
    obs, info = env.reset()
    reward = 0.0; terminated = False; truncated = False
    step = 0
    while not step_log or (not terminated and not truncated):
        # time.sleep(0.01)  # To slow down the rendering
        df = make_step_df()
        action = pid_policy(obs, df, debug=True)
        obs, reward, terminated, truncated, info = env.step(action)
        log_step(episode, step, action, obs, terminated, truncated, reward, info)
        step += 1

    # print(f'Total steps: {len(step_log)}')


print(f'Ran {n_episodes} episodes, total steps: {len(step_log)}')

step_df = make_step_df()
df = step_df

print(f'''
Episode stats:
{df[['episode', 'step', 'reward']].groupby("episode").agg({
    'step': 'max',
    'reward': 'sum',
})}

Mean:
{df[['episode', 'step', 'reward']].groupby("episode").agg({
    'step': 'max',
    'reward': 'sum',
}).mean()}
''')

from matplotlib import pyplot as plt
for episode in range(n_episodes):
    df = step_df[step_df.episode == episode]
    print(f'Episode {episode} - Total Reward: {df.reward.sum()}, Steps: {len(df)}')
    _ = plt.axhline(0, color='gray', linestyle='--')
    _ = plt.plot(df.index, df.x, label='x', color='gray')
    _ = plt.plot(df.index, df.theta / max_theta, label='theta (normalized)', color='blue')
    _ = plt.plot(df.index, df.dtheta / max_theta, label='dtheta (normalized)', color='lightblue', linestyle='--')
    _ = plt.plot(df.index, df.u / max_u, label='u (normalized)', color='green')
    _ = plt.ylim(-1.5, 1.5)
    _ = plt.legend()
    plt.show()
# Out:
# Ran 10 episodes, total steps: 2561
#
# Episode stats:
#          step  reward
# episode
# 0         234   234.0
# 1         307   307.0
# 2         205   205.0
# 3         332   332.0
# 4         281   281.0
# 5         269   269.0
# 6         217   217.0
# 7         213   213.0
# 8         270   270.0
# 9         223   223.0
#
# Mean:
# step      255.1
# reward    255.1
# dtype: float64
#
# Episode 0 - Total Reward: 234.0, Steps: 235
# Episode 1 - Total Reward: 307.0, Steps: 308
# Episode 2 - Total Reward: 205.0, Steps: 206
# Episode 3 - Total Reward: 332.0, Steps: 333
# Episode 4 - Total Reward: 281.0, Steps: 282
# Episode 5 - Total Reward: 269.0, Steps: 270
# Episode 6 - Total Reward: 217.0, Steps: 218
# Episode 7 - Total Reward: 213.0, Steps: 214
# Episode 8 - Total Reward: 270.0, Steps: 271
# Episode 9 - Total Reward: 223.0, Steps: 224

# %%
df.tail()
# Out:
#      episode  step                  action         u         x     theta  \
# 411        0   411  [[2.7478125365717916]]  2.747813  1.001823  0.077659
# 412        0   412                 [[3.0]]  3.000000  1.001857  0.107983
# 413        0   413                 [[3.0]]  3.000000  1.001917  0.140341
# 414        0   414                 [[3.0]]  3.000000  1.001954  0.175869
# 415        0   415                 [[3.0]]  3.000000  1.001970  0.215627
#
#            dx    dtheta                                                obs  \
# 411 -0.000837  0.744426  [[1.0018225747235565, 0.0776592134123073, -0.0...
# 412  0.001601  0.778296  [[1.0018572303959703, 0.10798256945462563, 0.0...
# 413  0.001232  0.844193  [[1.0019168283773054, 0.1403405853014649, 0.00...
# 414  0.000631  0.936587  [[1.0019536407912164, 0.17586869881217015, 0.0...
# 415  0.000238  1.055974  [[1.0019702990700181, 0.21562664346459864, 0.0...
#
#      reward terminated truncated  \
# 411     1.0    [False]   [False]
# 412     1.0    [False]   [False]
# 413     1.0    [False]   [False]
# 414     1.0    [False]   [False]
# 415     0.0     [True]   [False]
#
#                                                   info
# 411  {'reward_survive': [1], '_reward_survive': [Tr...
# 412  {'reward_survive': [1], '_reward_survive': [Tr...
# 413  {'reward_survive': [1], '_reward_survive': [Tr...
# 414  {'reward_survive': [1], '_reward_survive': [Tr...
# 415  {'reward_survive': [0], '_reward_survive': [Tr...

# %%
env.close()
