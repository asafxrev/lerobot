# %%
from lerobot.envs.utils import _load_module_from_path, _call_make_env, _normalize_hub_result

# Load your module
module = _load_module_from_path("./inverted_pendulum_env.py")

# Test the make_env function
result = _call_make_env(module, n_envs=1, use_async_envs=False)
normalized = _normalize_hub_result(result)

# Verify it works
suite_name = next(iter(normalized))
env = normalized[suite_name][0]
step_log = []

obs, info = env.reset()
reward = 0.0; terminated = False; truncated = False

# %%
mjmodel = env.envs[0].unwrapped.model

import mujoco as mj
cart_id = mj.mj_name2id(mjmodel, mj.mjtObj.mjOBJ_BODY, "cart")
pole_id = mj.mj_name2id(mjmodel, mj.mjtObj.mjOBJ_BODY, "pole")

m_c = mjmodel.body_mass[cart_id]
m_p = mjmodel.body_mass[pole_id]
l = 1
g = 9.81

import numpy as np
def f_t(ddx, ddtheta,                 # Decision variables
        x, dx, theta, dtheta,         # State: x, dx, tehta, dtheta
        m_c=m_c, m_p=m_p, l=l, g=g,   # Parameters: m_c, m_p, l, g
        min_f=-3, max_f=3) -> float:
    f_t = (
        (m_c + m_p) * ddx 
        - m_p * l * ddtheta * np.cos(theta) 
        + m_p * l * dtheta**2 * np.sin(theta))

    # print(f'Unclipped f_t: {f_t}')
    f_t = np.clip(f_t, min_f, max_f)
    return f_t


def decide_dd(x, theta, dx, dtheta,
              m_c=m_c, m_p=m_p, l=l, g=g,   # Parameters: m_c, m_p, l, g
              ) -> tuple[float, float]:
    ddtheta = - theta * 0.5  # Try to bring pole back to vertical
    # ddx = (ddtheta * l - g * np.sin(theta)) / np.cos(theta)
    ddx = l* ddtheta
    return (ddx, ddtheta)

    # if dx * x < 0:
    #     # If dx is in the right direction for returning to zero, keep ddx = 0
    #     ddx = 0
    # elif abs(dx) > 0:
    #     # Otherwise, gradually reverse course
    #     ddx = -dx / 10.0
    # elif abs(x) > 0:
    #     # If we are stationary but away from zero, accelerate back to zero
    #     ddx = -np.sign(x) * 0.1
    # else:
    #     ddx = 0
    # return ddx



def policy(obs, debug=True) -> np.ndarray:
    x, theta, dx, dtheta = obs[0]
    ddx, ddtheta = decide_dd(x, theta, dx, dtheta)
    if debug:
        print(f"Observation: x: {x}, theta: {theta}, dx: {dx}, dtheta: {dtheta}")
        print(f"Decided ddx: {ddx}, ddtheta: {ddtheta}")
    f_t_val = f_t(ddtheta, ddx, x, dx, 
                  theta=0,  # Force theta to zero
                  dtheta=dtheta)
    if debug:
        print(f"f_t: {f_t_val}")
    return np.array([[f_t_val]])

# %%
import numpy as np

K = (0.1, 0.0, 0.0, 0.0)  # Kx, Ktheta, Kdx, Kdtheta
def pid_policy(obs, debug=True) -> np.ndarray:
    u = np.dot(obs, K)
    return np.array([np.clip(u, -3, 3)])

# %%
step_log = [
]

def log_step(action, post_action_obs, terminated=False, truncated=False, 
             reward=[0.0], info={}):
    x, theta, dx, dtheta = post_action_obs[0]
    step_log.append(
        dict(
            action=action,
            u=action[0][0] if action is not None else 0.0,
            x=x,
            theta=theta,
            dx=dx,
            dtheta=dtheta,
            obs=post_action_obs,
            reward=reward[0] if reward is not None else 0.0,
            terminated=terminated,
            truncated=truncated,
            info=info,
        )
    )


log_step(None, obs)

while not step_log or not step_log[-1]['terminated']:
    action = pid_policy(obs, debug=True)
    obs, reward, terminated, truncated, info = env.step(action)
    log_step(action, obs, terminated, truncated, reward, info)


print(f'Total steps (including start): {len(step_log)}')

import pandas as pd
df = pd.DataFrame.from_records(step_log)
# Out:
# Total steps (including start): 22

# %%
df
# Out:
#                         action         u         x     theta        dx  \
# 0                         None  0.000000  0.047182  0.216184 -0.006192
# 1    [[0.0047182156217684765]]  0.004718 -0.026302  0.001980  0.046372
# 2   [[-0.0026301663057196572]] -0.002630 -0.024472  0.003401  0.045114
# 3   [[-0.0024471525506640497]] -0.002447 -0.022693  0.005037  0.043786
# 4    [[-0.002269306140561935]] -0.002269 -0.020969  0.006939  0.042370
# 5   [[-0.0020969410822495936]] -0.002097 -0.019305  0.009169  0.040842
# 6   [[-0.0019304567743391341]] -0.001930 -0.017704  0.011799  0.039172
# 7   [[-0.0017703592147739547]] -0.001770 -0.016173  0.014914  0.037324
# 8    [[-0.001617285243981255]] -0.001617 -0.014720  0.018613  0.035254
# 9   [[-0.0014720306642550536]] -0.001472 -0.013356  0.023018  0.032911
# 10  [[-0.0013355831491254798]] -0.001336 -0.012092  0.028271  0.030231
# 11   [[-0.001209160936989145]] -0.001209 -0.010943  0.034543  0.027138
# ...

# %%
from matplotlib import pyplot as plt
_ = plt.plot(df.u, df.theta)

# %%
# Run this as many times as you'd like
# action = -action

# action = env.action_space.sample()
# obs, reward, terminated, truncated, info = env.step(action)

terminated = False
i = 0
total_reward = 0.0
while not terminated and not truncated:
    print(f"Step {i}")
    action = policy(obs, debug=True)
    print(action)

    step_result = env.step(action)
    step_log.append(step_result)
    obs, reward, terminated, truncated, info = step_result
    total_reward += reward
    print('Observation: (x, theta, dx, dtheta) =', obs)
    print('Reward: ', reward)
    print(info)
    i += 1
    # print(obs, reward, terminated, truncated, info)


print("-" * 10 + " Episode ended " + "-" * 10)
if terminated and not truncated:
    print("Episode terminated!!!")
if truncated:
    print("Episode truncated!!!")

print(f"Total steps: {i} Total reward: {total_reward}")
# Out:
# Step 0
# Observation: x: -0.1062484360472728, theta: 0.2844575494714442, dx: -1.080216783595324, dtheta: 2.6840820239651384
# Decided ddx: -0.1422287747357221, ddtheta: -0.1422287747357221
# f_t: -1.4894162461294074
# [[-1.48941625]]
# Observation: (x, theta, dx, dtheta) = [[-0.00749196 -0.08535519  0.07083689 -0.02251612]]
# Reward:  [0.]
# {}
# Step 1
# Observation: x: -0.007491956683481416, theta: -0.08535518907907345, dx: 0.07083688823971013, dtheta: -0.02251611809766947
# Decided ddx: 0.04267759453953673, ddtheta: 0.04267759453953673
# f_t: 0.4469187249276416
# [[0.44691872]]
# Observation: (x, theta, dx, dtheta) = [[-0.00151104 -0.09499203  0.22771321 -0.45508867]]
# Reward:  [1.]
# {'reward_survive': array([1]), '_reward_survive': array([ True])}
# Step 2
# Observation: x: -0.0015110350918947442, theta: -0.0949920252467941, dx: 0.2277132110100402, dtheta: -0.45508866583977076
# Decided ddx: 0.04749601262339705, ddtheta: 0.04749601262339705
# f_t: 0.4973770811082409
# ...

# %%
step_log
# Out:
# [(array([[ 0.00949938, -0.1299001 ,  0.96504312, -2.3994961 ]]),
#   array([1.]),
#   array([False]),
#   array([False]),
#   {'reward_survive': array([1]), '_reward_survive': array([ True])}),
#  (array([[ 0.05820869, -0.24885104,  1.4679142 , -3.54399301]]),
#   array([0.]),
#   array([ True]),
#   array([False]),
#   {'reward_survive': array([0]), '_reward_survive': array([ True])}),
#  (array([[-0.05393489, -0.07017135, -0.04269913,  0.04514996]]),
#   array([0.]),
#   array([False]),
#   array([False]),
#   {}),
#  (array([[-0.03556498, -0.11588911,  0.95759387, -2.30361554]]),
#   array([1.]),
#   array([False]),
#   array([False]),
#   {'reward_survive': array([1]), '_reward_survive': array([ True])}),
#  (array([[ 0.01952336, -0.24613269,  1.79159796, -4.18912499]]),
#   array([0.]),
#   array([ True]),
#   array([False]),
#   {'reward_survive': array([0]), '_reward_survive': array([ True])})]

# %%
env.close()
